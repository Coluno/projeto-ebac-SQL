# %% [markdown]
# ## **Exploração e analise de dados de crédito com SQL**

# %% [markdown]
# **Dados:**
# - idade = idade do cliente
# - sexo = sexo do cliente (F ou M)
# - dependentes = número de dependentes do cliente
# - escolaridade = nível de escolaridade do clientes
# - salario_anual = faixa salarial do cliente
# - tipo_cartao = tipo de cartao do cliente
# - qtd_produtos = quantidade de produtos comprados nos últimos 12 meses
# - iteracoes_12m = quantidade de iterações/transacoes nos ultimos 12 meses
# - meses_inativo_12m = quantidade de meses que o cliente ficou inativo
# - limite_credito = limite de credito do cliente
# - valor_transacoes_12m = valor das transações dos ultimos 12 meses
# - qtd_transacoes_12m = quantidade de transacoes dos ultimos 12 meses
# A tabela foi criada no **AWS Athena** junto com o **S3 Bucket** com uma versão reduriza dos dados disponibilizados em: https://github.com/andre-marcos-perez/ebac-course-utils/tree/main/dataset

# %% [markdown]
# # **1.Exploração de dados:**

# %% [markdown]
# **Qual a quantidade de informações da base de dados?**
# > **Query**: select count(*) from credit
# > * Resposta: 2564

# %% [markdown]
# **Obs:** A base de dados do link acima contém mais linhas do que a seleção utilizada. Você pode utilizar todas as linhas ou considerar apenas uma fração dos dados. Na prática, quanto maior a quantidade de dados utilizada, mais confiável a análise! Mas existem limites computacionais e financeiros na qual a redução de dados para análise para fins de estudo se torna interessante.

# %% [markdown]
# **Como são os dados?**

# %% [markdown]
# **Query**: SELECT * FROM credito LIMIT 10;
# - ![como-sao-os-dados](https://github.com/Coluno/projeto-ebac-SQL/blob/main/imagens-sql-projeto/como-sao-os-dados.png?raw=true)
# > É possível reparar que existem algumas informações nulas na tabela (valor na), vamos olhar mais de perto para os valores de cada coluna.

# %% [markdown]
# **Quais os tipos de cada dado?**

# %% [markdown]
# **Query:** DESCRIBE credito
# - ![describe](https://github.com/Coluno/projeto-ebac-SQL/blob/main/imagens-sql-projeto/describe.png?raw=true)
# >Analise dos tipos de dados, vamos olhar mais atentamente para as varíaveis que não são numéricas.

# %% [markdown]
# **Quais são os tipos de escolaridade disponíveis no dataset?**

# %% [markdown]
# **Query:** SELECT DISTINCT escolaridade FROM credito
# - ![tipos-escolaridade](https://github.com/Coluno/projeto-ebac-SQL/blob/main/imagens-sql-projeto/tipos-escolaridade.png?raw=true)
# > Os dados contam com vários níveis de escolaridade e é possível perceber que temos valores nulos (na) no dataset, iremos tratar

# %% [markdown]
# **Quais são os tipos de estado_civil disponíveis no dataset?**

# %% [markdown]
# **Query:** SELECT DISTINCT estado_civil FROM credito
# - ![estado-civil](https://github.com/Coluno/projeto-ebac-SQL/blob/main/imagens-sql-projeto/estado-civil.png?raw=true)
# > Valores nulos nos dados de estado civil!

# %% [markdown]
# **Quais são os tipos de salario_anual disponíveis no dataset?**

# %% [markdown]
# **Query:** SELECT DISTINCT salario_anual FROM credito
# - ![salario-anual](https://github.com/Coluno/projeto-ebac-SQL/blob/main/imagens-sql-projeto/tipos-salario.png?raw=true)
# > Os salários nesse dataset não estão expostas com o valor exato que o cliente ganha. O que está informado é a faixa salarial de cada um. Também contem dados nulos.

# %% [markdown]
# **Quais são os tipos de cartão disponíveis no dataset?**

# %% [markdown]
# **Query**: SELECT DISTINCT tipo_cartao FROM credito
# - ![tipo-cartao](https://github.com/Coluno/projeto-ebac-SQL/blob/main/imagens-sql-projeto/tipo-cartao.png?raw=true)
# > Aqui vemos que não há necessidade de tratar valores nulos.

# %% [markdown]
# # **2. Analise de dados**

# %% [markdown]
# Uma vez que exploramos o dados e buscamos entender quais são as informações que temos no nosso banco de dados, podemos analisar as informações para buscar entender o que está acontecendo no banco de dados. Vamos fazer perguntas: / **Nesse banco de dados, quantos clientes temos de cada faixa salarial?**Query: select count(*), salario_anual from credito group by salario_anual

# %% [markdown]
# **Query**: select count(*), salario_anual from credito group by salario_anual
# ![clientes-faixa-salarial](https://github.com/Coluno/projeto-ebac-SQL/blob/main/imagens-sql-projeto/cliente-faixa-salario.png?raw=true)
# > a maioria dos clientes dessa base de dados possui um renda menor que 40K e existem 235 clientes que não informaram ou não consta a faixa salarial. De certa forma, pode ser interessante para a empresa focar nesse público de mais baixa renda.

# %% [markdown]
# **Nesse banco de dados, quantos clientes são homens e quantos são mulheres?**

# %% [markdown]
# **Query**: select count(*), sexo from credito group by sexo
# - ![sexo-por-cliente](https://github.com/Coluno/projeto-ebac-SQL/blob/main/imagens-sql-projeto/cliente-por-sexo.png?raw=true)
# - ![grafico-por-sexo](https://github.com/Coluno/projeto-ebac-SQL/blob/main/imagens-sql-projeto/grafico-pizza-f-m.png?raw=true)
# > A maioria dos clientes desse banco é homem! Do csv extraído dos dados é possível gerar o gráfico em pizza com para melhor a proporção de masculino/feminino

# %% [markdown]
# **Queremos focar o nosso marketing de maneira adequada para nossos clientes, qual será a idade deles?**

# %% [markdown]
# **Query**: select avg(idade) as media_idade, min(idade) as min_idade, max(idade) as max_idade, sexo from credito group by sexo
# - ![media-idade](https://github.com/Coluno/projeto-ebac-SQL/blob/main/imagens-sql-projeto/media-idade.png?raw=true)
# > Por meio dessa análise não foi possível extrair nenhuma informação relevante. A menor idade dos dois sexos é a mesma e a média é muito similar. A unica diferença é a idade máxima mas fato quase irrelevante por a diferença não é tão gritante.

# %% [markdown]
# **Qual a maior e menor transação dos clientes?**

# %% [markdown]
# **Query**: select min(valor_transacoes_12m) as transacao_minima, max(valor_transacoes_12m) as transacao_maxima from credito
# - ![transacao-minina-maxima](https://github.com/Coluno/projeto-ebac-SQL/blob/main/imagens-sql-projeto/transacao-minima-maxima.png?raw=true)]
# > Nesse banco de dados temos soma de transações em 12 meses variam de 510.16 a 4776.58

# %% [markdown]
# **Quais as características dos clientes que possuem os maiores creditos?**

# %% [markdown]
# **Query**: select max(limite_credito) as limite_credito, escolaridade, tipo_cartao, sexo from credito where escolaridade != 'na' and tipo_cartao != 'na' group by escolaridade, tipo_cartao, sexo order by limite_credito desc limit 10
# - ![clientes-maior-limite](https://github.com/Coluno/projeto-ebac-SQL/blob/main/imagens-sql-projeto/cliente-maior-limite.png?raw=true)
# > Não parece haver um impacto da escolaridade no limite. O limite mais alto é oferecido para um homem sem educação formal. O cartão também parece não estar relacionado com a escolaridade nem com o limite. Dentre os maiores limites, encontramos clientes com cartão: gold, silver, platinum e blue

# %% [markdown]
# **Quais as características dos clientes que possuem os menores creditos?**

# %% [markdown]
# **Query:** select max(limite_credito) as limite_credito, escolaridade, tipo_cartao, sexo from credito where escolaridade != 'na' and tipo_cartao != 'na' group by escolaridade, tipo_cartao, sexo order by limite_credito asc
# - ![caracteristica-maenor-credito](https://github.com/Coluno/projeto-ebac-SQL/blob/main/imagens-sql-projeto/cliente-menor-credito.png?raw=true)
# > Dessa vez conseguimos perceber que não há clientes com cartão platinum dentre os menores limites. Também foi possível perceber que a maioria dos menores limites são mulheres enquanto nos maiores limites predomina homens.

# %% [markdown]
# **Será que as mulheres gastam mais?**

# %% [markdown]
# **Query**: select max(valor_transacoes_12m) as maior_valor_gasto, avg(valor_transacoes_12m) as media_valor_gasto, min(valor_transacoes_12m) as min_valor_gasto, sexo from credito group by sexo
# - ![gastos-homens-mulheres](https://github.com/Coluno/projeto-ebac-SQL/blob/main/imagens-sql-projeto/gastos-homens-mulheres.png?raw=true)
# > Apesar da diferença nos limites, os gastos de homens e mulheres são similares!

# %% [markdown]
# **O salário impacta no limite?**

# %% [markdown]
# **Query**: select avg(qtd_produtos) as qts_produtos, avg(valor_transacoes_12m) as media_valor_transacoes, avg(limite_credito) as media_limite, sexo, salario_anual from credito where salario_anual != 'na' group by sexo, salario_anual order by avg(valor_transacoes_12m) desc
# - ![limite-credito](https://github.com/Coluno/projeto-ebac-SQL/blob/main/imagens-sql-projeto/limite-credito.png?raw=true)
# > SIM! As pessoas que tem menor faixa salarial também apresentam menor limite de credito!Conclusão

# %% [markdown]
# # 3. **Conclusão**

# %% [markdown]
# Essas foram **algumas** análises extraídas do dataset de crédito.
#
# Alguns insights interessantes:
#
# - a maior parte dos clientes possui renda até 40K
# - a maior parte dos clientes é masculino!
# - a escolaridade não parece influenciar no limite nem no tipo do cartão
# - os clientes com maiores limites são em sua maioria homens
# - os clientes com menores limites são em sua maioria mulheres
# - dentre os menores limites não há presença de cartão platinum
# - a faixa salarial impacta diretamente no limite de crédito
# - nao existem clientes com salário anual acima de 60K do sexo feminino
